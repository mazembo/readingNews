# %%
import getlinks as gl

# %%
import re

# %%
jeuneafrique = "http://www.jeuneafrique.com/pays/rd-congo/"

# %%
jeuneafrique_html, date_accessed = gl.getHtml(jeuneafrique)

# %%
jeuneafrique_links = gl.jeuneafriqueLinks(jeuneafrique_html, jeuneafrique)

# %%
jeuneafrique_links_final = []

# %%
print jeuneafrique_links
# Out:
# ['http://www.jeuneafrique.com/423379/societe/firmin-mubele-a-rennes-christian-gourcuff-me-confiance/', 'http://www.jeuneafrique.com/430547/societe/rdc-pamphile-mihayo-nomme-entraineur-tp-mazembe/', 'http://www.jeuneafrique.com/432796/societe/football-pamphile-mihayo-tp-mazembe-periode-de-transition/', 'http://www.jeuneafrique.com/443610/societe/football-youri-tielemans-nouvelle-pepite-belgo-congolaise-de-monaco/', 'http://www.jeuneafrique.com/446265/societe/lukaku-aurier-pogba-abdennour-dossiers-a-suivre-debut-mercato/', 'http://www.jeuneafrique.com/447481/politique/rdc-miliciens-de-kamuina-nsapu-derriere-levasion-de-prison-de-matete/', 'http://www.jeuneafrique.com/457547/politique/burundi-retour-sejour-rocambolesque-de-koffi-olomide-a-bujumbura/', 'http://www.jeuneafrique.com/457643/politique/concert-parisien-dheritier-watanabe-interdit-apres-debordements-dopposants-a-joseph-kabila/', 'http://www.jeuneafrique.com/464144/politique/rdc-nouvelle-attaque-de-la-prison-de-makala-repoussee
# ...

# %%
print len(jeuneafrique_links)
# Out:
# 79

# %%
for link in jeuneafrique_links:
    print link
# Out:
# http://www.jeuneafrique.com/423379/societe/firmin-mubele-a-rennes-christian-gourcuff-me-confiance/
# http://www.jeuneafrique.com/430547/societe/rdc-pamphile-mihayo-nomme-entraineur-tp-mazembe/
# http://www.jeuneafrique.com/432796/societe/football-pamphile-mihayo-tp-mazembe-periode-de-transition/
# http://www.jeuneafrique.com/443610/societe/football-youri-tielemans-nouvelle-pepite-belgo-congolaise-de-monaco/
# http://www.jeuneafrique.com/446265/societe/lukaku-aurier-pogba-abdennour-dossiers-a-suivre-debut-mercato/
# http://www.jeuneafrique.com/447481/politique/rdc-miliciens-de-kamuina-nsapu-derriere-levasion-de-prison-de-matete/
# http://www.jeuneafrique.com/457547/politique/burundi-retour-sejour-rocambolesque-de-koffi-olomide-a-bujumbura/
# http://www.jeuneafrique.com/457643/politique/concert-parisien-dheritier-watanabe-interdit-apres-debordements-dopposants-a-joseph-kabila/
# ...

# %%
for link in jeuneafrique_links:
    print link
# Out:
# http://www.jeuneafrique.com/423379/societe/firmin-mubele-a-rennes-christian-gourcuff-me-confiance/
# http://www.jeuneafrique.com/430547/societe/rdc-pamphile-mihayo-nomme-entraineur-tp-mazembe/
# http://www.jeuneafrique.com/432796/societe/football-pamphile-mihayo-tp-mazembe-periode-de-transition/
# http://www.jeuneafrique.com/443610/societe/football-youri-tielemans-nouvelle-pepite-belgo-congolaise-de-monaco/
# http://www.jeuneafrique.com/446265/societe/lukaku-aurier-pogba-abdennour-dossiers-a-suivre-debut-mercato/
# http://www.jeuneafrique.com/447481/politique/rdc-miliciens-de-kamuina-nsapu-derriere-levasion-de-prison-de-matete/
# http://www.jeuneafrique.com/457547/politique/burundi-retour-sejour-rocambolesque-de-koffi-olomide-a-bujumbura/
# http://www.jeuneafrique.com/457643/politique/concert-parisien-dheritier-watanabe-interdit-apres-debordements-dopposants-a-joseph-kabila/
# ...

# %%
benilubero = "http://benilubero.com/"

# %%
benilubero_html, date_accessed = gl.getHtml(benilubero)

# %%
import requests

# %% [raw]
# r = requests.get(benilubero)

# %% [raw]
# r.content

# %%
print "hello"
# Out:
# hello

# %%
benilubero_links = gl.beniluberoLinks(benilubero_html, benilubero)

# %% [raw]
# for link in benilubero_links:
#     print link

# %%
print benilubero_links
# Out:
# ['http://benilubero.com/', 'http://benilubero.com//', 'http://benilubero.com/10-questions-a-bruno-tshibala-porte-parole-des-frondeurs-du-rassemblement/', 'http://benilubero.com/10-questions-a-bruno-tshibala-porte-parole-des-frondeurs-du-rassemblement/#respond', 'http://benilubero.com/13371-2/', 'http://benilubero.com/13371-2/#respond', 'http://benilubero.com/14295-2/', 'http://benilubero.com/14295-2/#respond', 'http://benilubero.com/14996-2/', 'http://benilubero.com/14996-2/#respond', 'http://benilubero.com/15806-2/', 'http://benilubero.com/15806-2/#respond', 'http://benilubero.com/15882-2/', 'http://benilubero.com/15882-2/#respond', 'http://benilubero.com/16314-2/', 'http://benilubero.com/16314-2/#respond', 'http://benilubero.com/16485-2/', 'http://benilubero.com/16485-2/#respond', 'http://benilubero.com/16792-2/', 'http://benilubero.com/16792-2/#respond', 'http://benilubero.com/16886-2/', 'http://benilubero.com/16886-2/#respond', 'http://benilubero.com/17e-anniversaire-de-lhorreur-
# ...

# %%
print len(benilubero_links)
# Out:
# 1023

# %%
url2 = "http://www.africanewsrdc.com"

# %%
potentiel_url = "https://www.lepotentielonline.com"

# %%
prosperite_url = "https://laprosperiteonline.net"

# %%
mediacongo_url = "http://www.mediacongo.net"

# %%
congoindependant_url = "http://www.congoindependant.com"

# %%
cheikfitanews_url = "http://www.cheikfitanews.net"

# %%
voiceofcongo_url = "http://www.voiceofcongo.net"

# %%
sangoyacongo_url = "http://www.sangoyacongo.com"

# %%
voafrique_url = "https://www.voaafrique.com/p/4938.html"

# %%
bbcafrique_url = "http://www.bbc.com/afrique/region"

# %%
lemonde_url = "http://www.lemonde.fr/congo-rdc/"

# %%
africanews_html, date_accessed_africanews = gl.getHtml(url2)

# %%
prosperite_html, date_accessed_prosperite = gl.getHtml(prosperite_url)

# %%
potentiel_html, date_accessed_potentiel = gl.getHtml(potentiel_url)

# %%
mediacongo_html, date_accessed_mediacongo = gl.getHtml(mediacongo_url)

# %%
congoindependant_html, date_accessed_congoindependant = gl.getHtml(congoindependant_url)

# %%
cheikfitanews_html, date_accessed_cheikfitanews = gl.getHtml(cheikfitanews_url)

# %%
voiceofcongo_html, date_accessed_voiceofcongo = gl.getHtml(voiceofcongo_url)

# %%
sangoyacongo_html, date_accessed_sango = gl.getHtml(sangoyacongo_url)

# %%
voafrique_html, date_accessed_voafrique = gl.getHtml(voafrique_url)

# %%
bbcafrique_html, date_accessed_bbc = gl.getHtml(bbcafrique_url)

# %%
lemonde_html, date_accessed_lemonde = gl.getHtml(lemonde_url)

# %%
potentiel_links = gl.genericLinks(potentiel_html, potentiel_url)

# %%
print potentiel_links
# Out:
# ['https://www.lepotentielonline.com#page', 'https://www.lepotentielonline.com/index.php?option=com_allvideoshare&amp;view=video&amp;slg=0&amp;orderby=latest&amp;Itemid=483', 'https://www.lepotentielonline.com/index.php?option=com_allvideoshare&amp;view=video&amp;slg=on-line-interview-paty-2&amp;orderby=latest', 'https://www.lepotentielonline.com/index.php?option=com_allvideoshare&amp;view=video&amp;slg=on-line-omos-diaspora-kin&amp;orderby=latest', 'https://www.lepotentielonline.com/index.php?option=com_contact&amp;view=contact&amp;id=9&amp;Itemid=520', 'https://www.lepotentielonline.com/index.php?option=com_content&amp;view=article&amp;id=11994&amp;Itemid=667', 'https://www.lepotentielonline.com/index.php?option=com_content&amp;view=article&amp;id=15460:revue-de-presse-congolaise-de-lundi-10-octobre-2016&amp;catid=110:revue-de-presse', 'https://www.lepotentielonline.com/index.php?option=com_content&amp;view=article&amp;id=15601:revue-de-presse-congolaise-de-mardi-25-octobre-2016&amp
# ...

# %%
print len(potentiel_links)
# Out:
# 259
